# %%
import pandas as pd
df = pd.read_csv("eurocup_2020_results.csv")
df.head()
# Out:
#               stage          date   pens pens_home_score pens_away_score  \
# 0            Final     11.07.2021   True               3               2
# 1      Semi-finals    07.07.2021   False           False           False
# 2      Semi-finals     06.07.2021   True               4               2
# 3   Quarter-finals    03.07.2021   False           False           False
# 4   Quarter-finals    03.07.2021   False           False           False
#
#      team_name_home team_name_away  team_home_score  team_away_score  \
# 0            Italy        England                 1                1
# 1          England        Denmark                 2                1
# 2            Italy          Spain                 1                1
# 3          Ukraine        England                 0                4
# 4   Czech Republic        Denmark                 1                2
#
#   possession_home possession_away  total_shots_home  total_shots_away  \
# ...

# %%
df.describe()
# Out:
#        team_home_score  team_away_score  total_shots_home  total_shots_away  \
# count        51.000000        51.000000         51.000000         51.000000
# mean          1.196078         1.588235         12.137255         12.235294
# std           1.077397         1.344269          6.190378          5.788223
# min           0.000000         0.000000          3.000000          1.000000
# 25%           0.000000         1.000000          7.000000          8.500000
# 50%           1.000000         1.000000         11.000000         11.000000
# 75%           2.000000         2.000000         17.000000         16.000000
# max           3.000000         5.000000         27.000000         28.000000
#
#        shots_on_target_home  shots_on_target_away
# count             51.000000             51.000000
# mean               3.803922              4.352941
# std                2.545738              2.681966
# min                0.000000              0.000000
# ...

# %%
df.columns
# Out:
# Index(['stage', 'date', 'pens', 'pens_home_score', 'pens_away_score',
#        'team_name_home', 'team_name_away', 'team_home_score',
#        'team_away_score', 'possession_home', 'possession_away',
#        'total_shots_home', 'total_shots_away', 'shots_on_target_home',
#        'shots_on_target_away', 'duels_won_home', 'duels_won_away',
#        'events_list', 'lineup_home', 'lineup_away'],
#       dtype='object')

# %%
df['stage'].unique()
# Out:
# array([' Final ', ' Semi-finals ', ' Quarter-finals ', ' Round of 16 ',
#        ' Group stage: Matchday 3 ', ' Group stage: Matchday 2 ',
#        ' Group stage: Matchday 1 '], dtype=object)

# %%
df['date'].unique()
# Out:
# array(['11.07.2021', ' 07.07.2021 ', '06.07.2021', ' 03.07.2021 ',
#        ' 02.07.2021 ', '02.07.2021', ' 29.06.2021 ', '28.06.2021',
#        ' 28.06.2021 ', ' 27.06.2021 ', ' 26.06.2021 ', ' 23.06.2021 ',
#        ' 22.06.2021 ', ' 21.06.2021 ', ' 20.06.2021 ', ' 19.06.2021 ',
#        ' 18.06.2021 ', ' 17.06.2021 ', ' 16.06.2021 ', ' 15.06.2021 ',
#        ' 14.06.2021 ', ' 13.06.2021 ', ' 12.06.2021 ', ' 11.06.2021 '],
#       dtype=object)

# %%
df['pens'].value_counts()
# Out:
# False    47
# True      4
# Name: pens, dtype: int64

# %%
df['pens_home_score', ]
# Out:
# 0         3
# 1     False
# 2         4
# 3     False
# 4     False
# 5     False
# 6         1
# 7     False
# 8     False
# 9         4
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# Name: pens_home_score, dtype: object
